# %% [markdown]
# # Statistik Deskriptif

# %%
library(magrittr)

# %%
datakab = readRDS('datakab.rds')

# %%
library(summarytools)
dfSummary(datakab) %>% print
# Out:
# Data Frame Summary
# datakab
# Dimensions: 12012 x 19
# Duplicates: 0
#
# --------------------------------------------------------------------------------------------------------------------
# No   Variable        Stats / Values                    Freqs (% of Valid)   Graph                 Valid    Missing
# ---- --------------- --------------------------------- -------------------- --------------------- -------- ---------
# 1    region_name     1. Aceh Barat Daya, Kab.             22 ( 0.2%)                              12012    0
#      [character]     2. Aceh Barat, Kab.                  22 ( 0.2%)                              (100%)   (0%)
#                      3. Aceh Besar, Kab.                  22 ( 0.2%)
#                      4. Aceh Jaya, Kab.                   22 ( 0.2%)
#                      5. Aceh Selatan, Kab.                22 ( 0.2%)
#                      6. Aceh Singkil, Kab.                22 ( 0.2%)
# ...
